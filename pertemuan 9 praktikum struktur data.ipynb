# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

# Membuat tree secara manual
root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.left.left = Node(4)
root.left.right = Node(5)

# Fungsi inorder traversal
def inorder(node):
    if node:
        inorder(node.left)
        print(node.data, end=' ')
        inorder(node.right)

print("Hasil inorder traversal dari binary tree:")
inorder(root)

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

class BinarySearchTree:
    def __init__(self):
        self.root = None

    def insert(self, root, data):
        if root is None:
            return Node(data)
        if data < root.data:
            root.left = self.insert(root.left, data)
        else:
            root.right = self.insert(root.right, data)
        return root

bst = BinarySearchTree()
root = None
data_list = [50, 30, 70, 20, 40, 60, 80]
for value in data_list:
    root = bst.insert(root, value)

# %%
def inorder(node):
    if node:
        inorder(node.left)
        print(node.data, end=' ')
        inorder(node.right)

def preorder(node):
    if node:
        print(node.data, end=' ')
        preorder(node.left)
        preorder(node.right)

def postorder(node):
    if node:
        postorder(node.left)
        postorder(node.right)
        print(node.data, end=' ')

print("Inorder Traversal:")
inorder(root)
print("\nPreorder Traversal:")
preorder(root)
print("\nPostorder Traversal:")
postorder(root)

# %%
def search(node, key):
    if node is None or node.data == key:
        return node
    if key < node.data:
        return search(node.left, key)
    return search(node.right, key)

# Uji pencarian
key = 60
result = search(root, key)
if result:
    print(f"{key} ditemukan dalam tree.")
else:
    print(f"{key} tidak ditemukan.")

# %%
"""
Struktur Tree berdasarkan identitas saya
Nama Lengkap: Ahmad Budi Santoso (misal, jumlah huruf = 17)
Jumlah huruf vokal: a,a,u,i,a,o,o = 7 huruf vokal
Dua digit terakhir NPM: misal NPM = 202410123456 -> 56
Tanggal lahir: DD = 17, MM = 08
"""

class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

# Membuat tree secara manual berdasarkan identitas
# Root = jumlah huruf pada nama lengkap
root = Node(18)

# Anak kiri root = jumlah huruf vokal (misal 8)
root.left = Node(8)

# Anak kanan root = dua digit terakhir NPM (misal 28)
root.right = Node(28)

# Anak kiri dari node kiri = tanggal lahir (DD = 26)
root.left.left = Node(26)

# Anak kanan dari node kanan = bulan lahir (MM = 6)
root.right.right = Node(6)

# Fungsi inorder traversal
def inorder(node):
    if node:
        inorder(node.left)
        print(node.data, end=' ')
        inorder(node.right)

print("Hasil inorder traversal dari binary tree (berdasarkan identitas):")
inorder(root)
print()
# Out:
# Hasil inorder traversal dari binary tree (berdasarkan identitas):
# 26 8 18 28 6

# %%
"""
Program BST berdasarkan identitas saya
- Tiga digit terakhir NPM: misal 456
- Tanggal lahir DDMM: misal 1708 -> DD=17, MM=8
- ASCII huruf pertama dan kedua nama depan:
    Nama depan = Ahmad -> A=65, h=104
- Dua angka bebas: misal 100 dan 200
"""

class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

class BinarySearchTree:
    def __init__(self):
        self.root = None

    def insert(self, root, data):
        if root is None:
            return Node(data)
        if data < root.data:
            root.left = self.insert(root.left, data)
        else:
            root.right = self.insert(root.right, data)
        return root

    def inorder(self, node):
        if node:
            self.inorder(node.left)
            print(node.data, end=' ')
            self.inorder(node.right)

    def preorder(self, node):
        if node:
            print(node.data, end=' ')
            self.preorder(node.left)
            self.preorder(node.right)

    def postorder(self, node):
        if node:
            self.postorder(node.left)
            self.postorder(node.right)
            print(node.data, end=' ')

    def search(self, node, key):
        if node is None or node.data == key:
            return node
        if key < node.data:
            return self.search(node.left, key)
        return self.search(node.right, key)

# Data sesuai ketentuan
# 1. Tiga digit terakhir NPM: 228
# 2. Tanggal lahir (DD dan MM): 26 dan 6
# 3. ASCII huruf pertama dan kedua nama depan: M= 77, u = 117
# 4. Dua angka bebas: 96 dan 216
data_list = [228, 26, 6, 77, 117, 96, 216]

bst = BinarySearchTree()
root = None

# Memasukkan semua data ke BST
for value in data_list:
    root = bst.insert(root, value)

print("=== BST Berdasarkan Identitas ===")
print("Data yang dimasukkan:", data_list)
print()

# Traversal
print("Inorder Traversal (terurut):")
bst.inorder(root)
print("\n")

print("Preorder Traversal:")
bst.preorder(root)
print("\n")

print("Postorder Traversal:")
bst.postorder(root)
print("\n")

# Pencarian 1: dua digit terakhir NPM (misal 28)

search_key1 = 28
print(f"\nMencari angka {search_key1} (dua digit terakhir NPM):")
result1 = bst.search(root, search_key1)
if result1:
    print(f"✓ {search_key1} ditemukan dalam tree.")
else:
    print(f"✗ {search_key1} tidak ditemukan dalam tree.")

# Pencarian 2: angka yang tidak ada dalam list (misal 999)
search_key2 = 999
print(f"\nMencari angka {search_key2} (tidak ada dalam list):")
result2 = bst.search(root, search_key2)
if result2:
    print(f"✓ {search_key2} ditemukan dalam tree.")
else:
    print(f"✗ {search_key2} tidak ditemukan dalam tree.")
# Out:
# === BST Berdasarkan Identitas ===
# Data yang dimasukkan: [228, 26, 6, 77, 117, 96, 216]
#
# Inorder Traversal (terurut):
# 6 26 77 96 117 216 228
#
# Preorder Traversal:
# 228 26 6 77 117 96 216
#
# Postorder Traversal:
# 6 96 216 117 77 26 228
#
#
# Mencari angka 28 (dua digit terakhir NPM):
# ✗ 28 tidak ditemukan dalam tree.
#
# Mencari angka 999 (tidak ada dalam list):
# ✗ 999 tidak ditemukan dalam tree.
