# %%
def bubble_sort(arr):
    n = len(arr)
    for i in range(n - 1):
        for j in range(n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
    return arr

# Contoh penggunaan
data = [64, 34, 25, 12, 22, 11, 90]
sorted_data = bubble_sort(data.copy())  # Menggunakan copy agar data asli tidak berubah
print("Data sebelum sorting:", data)
print("Data setelah Bubble Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 34, 25, 12, 22, 11, 90]
# Data setelah Bubble Sort: [11, 12, 22, 25, 34, 64, 90]

# %%
def selection_sort(arr):
    n = len(arr)
    for i in range(n - 1):
        min_index = i
        for j in range(i + 1, n):
            if arr[j] < arr[min_index]:
                min_index = j
        arr[i], arr[min_index] = arr[min_index], arr[i]
    return arr

# Contoh penggunaan
data = [64, 25, 12, 22, 11]
sorted_data = selection_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Selection Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 25, 12, 22, 11]
# Data setelah Selection Sort: [11, 12, 22, 25, 64]

# %%
def insertion_sort(arr):
    n = len(arr)
    for i in range(1, n):
        key = arr[i]
        j = i - 1
        while j >= 0 and arr[j] > key:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key
    return arr

# Contoh penggunaan
data = [64, 34, 25, 12, 22, 11, 90]
sorted_data = insertion_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Insertion Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 34, 25, 12, 22, 11, 90]
# Data setelah Insertion Sort: [11, 12, 22, 25, 34, 64, 90]

# %%
def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2
        left_half = arr[:mid]
        right_half = arr[mid:]

        merge_sort(left_half)
        merge_sort(right_half)

        i = j = k = 0

        while i < len(left_half) and j < len(right_half):
            if left_half[i] < right_half[j]:
                arr[k] = left_half[i]
                i += 1
            else:
                arr[k] = right_half[j]
                j += 1
            k += 1

        while i < len(left_half):
            arr[k] = left_half[i]
            i += 1
            k += 1

        while j < len(right_half):
            arr[k] = right_half[j]
            j += 1
            k += 1

    return arr

# Contoh penggunaan
data = [64, 25, 12, 22, 11]
sorted_data = merge_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Merge Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 25, 12, 22, 11]
# Data setelah Merge Sort: [11, 12, 22, 25, 64]

# %%
def quick_sort(arr):
    if len(arr) <= 1:
        return arr

    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]

    return quick_sort(left) + middle + quick_sort(right)

# Contoh penggunaan
data = [64, 25, 12, 22, 11]
sorted_data = quick_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Quick Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 25, 12, 22, 11]
# Data setelah Quick Sort: [11, 12, 22, 25, 64]

# %%
def quick_sort(arr, key, reverse=False):
    if len(arr) <= 1:
        return arr

    # Pilih pivot (elemen tengah)
    pivot = arr[len(arr) // 2][key]

    # Bagi menjadi left, middle, right
    if reverse:
        # Untuk rating: descending (besar ke kecil)
        left = [x for x in arr if x[key] > pivot]
        middle = [x for x in arr if x[key] == pivot]
        right = [x for x in arr if x[key] < pivot]
    else:
        # Untuk harga: ascending (kecil ke besar)
        left = [x for x in arr if x[key] < pivot]
        middle = [x for x in arr if x[key] == pivot]
        right = [x for x in arr if x[key] > pivot]

    return quick_sort(left, key, reverse) + middle + quick_sort(right, key, reverse)


# ============================================
Daftar Produk di Marketplace
# ============================================
produk = [
    {"nama": "Smartphone X", "harga": 3500000, "rating": 4.5},
    {"nama": "Laptop Y", "harga": 8500000, "rating": 4.8},
    {"nama": "Headphone Z", "harga": 450000, "rating": 4.2},
    {"nama": "Powerbank A", "harga": 250000, "rating": 4.0},
    {"nama": "Smartwatch B", "harga": 1200000, "rating": 4.6},
    {"nama": "Tablet C", "harga": 2800000, "rating": 4.3},
    {"nama": "Speaker D", "harga": 750000, "rating": 4.4},
    {"nama": "Charger E", "harga": 150000, "rating": 3.9},
    {"nama": "Mouse F", "harga": 180000, "rating": 4.1},
    {"nama": "Keyboard G", "harga": 350000, "rating": 4.7}
]

print("=" * 60)
print("DATA PRODUK AWAL")
print("=" * 60)
for p in produk:
    print(f"{p['nama']:<15} | Harga: Rp{p['harga']:>10,} | Rating: {p['rating']}")

# ============================================
# 1. Sorting berdasarkan HARGA (termurah ke termahal)
# ============================================
print("\n" + "=" * 60)
print("PRODUK SETELAH DIURUTKAN BERDASARKAN HARGA (TERMURAH -> TERMAHAL)")
print("=" * 60)

produk_by_harga = quick_sort(produk.copy(), key="harga", reverse=False)
for p in produk_by_harga:
    print(f"{p['nama']:<15} | Harga: Rp{p['harga']:>10,} | Rating: {p['rating']}")

# ============================================
# 2. Sorting berdasarkan RATING (tertinggi ke terendah)
# ============================================
print("\n" + "=" * 60)
print("PRODUK SETELAH DIURUTKAN BERDASARKAN RATING (TERTINGGI -> TERENDAH)")
print("=" * 60)

produk_by_rating = quick_sort(produk.copy(), key="rating", reverse=True)
for p in produk_by_rating:
    print(f"{p['nama']:<15} | Harga: Rp{p['harga']:>10,} | Rating: {p['rating']}")
# Out:
# ...
# DATA PRODUK AWAL
# ...
# Smartphone X    | Harga: Rp 3,500,000 | Rating: 4.5
# Laptop Y        | Harga: Rp 8,500,000 | Rating: 4.8
# Headphone Z     | Harga: Rp   450,000 | Rating: 4.2
# Powerbank A     | Harga: Rp   250,000 | Rating: 4.0
# Smartwatch B    | Harga: Rp 1,200,000 | Rating: 4.6
# Tablet C        | Harga: Rp 2,800,000 | Rating: 4.3
# Speaker D       | Harga: Rp   750,000 | Rating: 4.4
# Charger E       | Harga: Rp   150,000 | Rating: 3.9
# Mouse F         | Harga: Rp   180,000 | Rating: 4.1
# Keyboard G      | Harga: Rp   350,000 | Rating: 4.7
#
# ...
# PRODUK SETELAH DIURUTKAN BERDASARKAN HARGA (TERMURAH -> TERMAHAL)
# ...
# Charger E       | Harga: Rp   150,000 | Rating: 3.9
# Mouse F         | Harga: Rp   180,000 | Rating: 4.1
# Powerbank A     | Harga: Rp   250,000 | Rating: 4.0
# Keyboard G      | Harga: Rp   350,000 | Rating: 4.7
# Headphone Z     | Harga: Rp   450,000 | Rating: 4.2
# Speaker D       | Harga: Rp   750,000 | Rating: 4.4
# ...
