# %%
class Node:
    def __init__(self, dataval=None):
        self.dataval = dataval
        self.nextval = None

n1 = Node("Senin")
n2 = Node("Selasa")
n3 = Node("Rabu")

class LinkedList:
    def __init__(self):
        self.headval = None

list1 = LinkedList()
list1.headval = n1
n1.nextval = n2
n2.nextval = n3

print(n1.dataval)
# Out:
# Senin

# %%
class Node:
    def __init__(self, dataval=None):
        self.dataval = dataval
        self.nextval = None

class LinkedList:
    def __init__(self):
        self.headval = None

    def listprint(self):
        printval = self.headval
        while printval is not None:
            print(printval.dataval)
            printval = printval.nextval

n1 = Node("Senin")
n2 = Node("Selasa")
n3 = Node("Rabu")

list1 = LinkedList()
list1.headval = n1
n1.nextval = n2
n2.nextval = n3

list1.listprint()
# Out:
# Senin
# Selasa
# Rabu

# %%
class Node:
    def __init__(self, dataval=None):
        self.dataval = dataval
        self.nextval = None

class LinkedList:
    def __init__(self):
        self.headval = None

    def listprint(self):
        printval = self.headval
        while printval is not None:
            print(printval.dataval)
            printval = printval.nextval

    def AtBeginning(self, newdata):
        NewNode = Node(newdata)
        NewNode.nextval = self.headval
        self.headval = NewNode

n1 = Node("Senin")
n2 = Node("Selasa")
n3 = Node("Rabu")

list1 = LinkedList()
list1.headval = n1
n1.nextval = n2
n2.nextval = n3

list1.AtBeginning("Minggu")
list1.listprint()
# Out:
# Minggu
# Senin
# Selasa
# Rabu

# %%
class Node:
    def __init__(self, dataval=None):
        self.dataval = dataval
        self.nextval = None

class LinkedList:
    def __init__(self):
        self.headval = None

    def listprint(self):
        printval = self.headval
        while printval is not None:
            print(printval.dataval)
            printval = printval.nextval

    def Inbetween(self, middle_node, newdata):
        if middle_node is None:
            print("Node yang dimaksud tidak ada")
            return
        NewNode = Node(newdata)
        NewNode.nextval = middle_node.nextval
        middle_node.nextval = NewNode

    def AtEnd(self, newdata):
        NewNode = Node(newdata)
        if self.headval is None:
            self.headval = NewNode
            return
        last = self.headval
        while last.nextval:
            last = last.nextval
        last.nextval = NewNode

n1 = Node("Senin")
n2 = Node("Selasa")
n3 = Node("Rabu")

list1 = LinkedList()
list1.headval = n1
n1.nextval = n2
n2.nextval = n3

list1.AtEnd("Kamis")
list1.Inbetween(n2, "Bilek")
list1.listprint()
# Out:
# Senin
# Selasa
# Bilek
# Rabu
# Kamis

# %%
class Node:
    def __init__(self, dataval=None):
        self.dataval = dataval
        self.nextval = None

class LinkedList:
    def __init__(self):
        self.headval = None

    def listprint(self):
        printval = self.headval
        while printval is not None:
            print(printval.dataval)
            printval = printval.nextval

    def RemoveNode(self, removekey):
        HeadVal = self.headval
        if HeadVal is not None:
            if HeadVal.dataval == removekey:
                self.headval = HeadVal.nextval
                HeadVal = None
                return
        while HeadVal is not None:
            if HeadVal.dataval == removekey:
                break
            prev = HeadVal
            HeadVal = HeadVal.nextval
        if HeadVal == None:
            return
        prev.nextval = HeadVal.nextval
        HeadVal = None

n1 = Node("Senin")
n2 = Node("Selasa")
n3 = Node("Rabu")

list1 = LinkedList()
list1.headval = n1
n1.nextval = n2
n2.nextval = n3

list1.RemoveNode("Selasa")
list1.listprint()
# Out:
# Senin
# Rabu

# %%
class Node:
    def __init__(self, dataval=None):
        self.dataval = dataval
        self.nextval = None

class LinkedList:
    def __init__(self):
        self.headval = None

    def listprint(self):
        printval = self.headval
        while printval is not None:
            print(printval.dataval)
            printval = printval.nextval

    def RemoveFirst(self):
        if self.headval is None:
            return
        temp = self.headval
        self.headval = self.headval.nextval
        temp = None

n1 = Node("Senin")
n2 = Node("Selasa")
n3 = Node("Rabu")

list1 = LinkedList()
list1.headval = n1
n1.nextval = n2
n2.nextval = n3

list1.RemoveFirst()
list1.listprint()
# Out:
# Selasa
# Rabu

# %%
class Node:
    def __init__(self, dataval=None):
        self.dataval = dataval
        self.nextval = None

class LinkedList:
    def __init__(self):
        self.headval = None

    def listprint(self):
        printval = self.headval
        while printval is not None:
            print(printval.dataval)
            printval = printval.nextval

    def RemoveLast(self):
        if self.headval is None:
            return
        if self.headval.nextval is None:
            self.headval = None
            return
        prev = None
        last = self.headval
        while last.nextval:
            prev = last
            last = last.nextval
        prev.nextval = None
        last = None

n1 = Node("Senin")
n2 = Node("Selasa")
n3 = Node("Rabu")

list1 = LinkedList()
list1.headval = n1
n1.nextval = n2
n2.nextval = n3

list1.RemoveLast()
list1.listprint()
# Out:
# Senin
# Selasa
